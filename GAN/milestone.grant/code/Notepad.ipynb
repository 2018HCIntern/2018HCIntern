# %%
import pandas as pd
df2 = pd.read_csv('../data/train_preprocessed2.csv')

# %%
import numpy as np
def get_unique(df):
    categories = { }
    length = len(df)
    threshold = length // 20
    for col in df.columns:
        unique = np.sort(df[col].unique())
        if df[col].dtype == np.int or len(unique) < threshold:
            categories[col] = unique
    return categories

# %%
def round_list(categories, df):
    for col in categories:
        print(col)
        rounder = categories[col]
        for i in range(len(df)):
            df[col][i] = round_val(rounder, df[col][i])

# %%
categories = get_unique(df)
len(categories)
# Out:
# 71

# %%
df = df + 0.1

# %%
round_list(categories, df)
# Out:
# A..papers
# A.papers
# B.papers
# C.papers
# Dif.countries
# Perc_non_australian
# Number.people
# PHD
# Max.years.univ
# Grants.succ
# Grants.unsucc
# Departments
# Perc.Lang.Eng
# Perc.Lang.Other
# Dif.Role
# Perc.CHIEF.INVESTIGATOR
# Average.Age
# Weekday
# Month
# Day.of.Month
# Day.of.Year
# Season
# Sponsor.Code
# Grant.Category.Code
# Contract.Value.Band
# RFCD.0
# RFCD.1
# RFCD.2
# RFCD.3
# RFCD.4
# RFCD.5
# RFCD.6
# RFCD.7
# RFCD.8
# RFCD.9
# RFCD.10
# RFCD.11
# RFCD.12
# RFCD.13
# RFCD.14
# RFCD.15
# RFCD.16
# RFCD.17
# RFCD.18
# RFCD.19
# RFCD.20
# RFCD.21
# RFCD.22
# RFCD.23
# RFCD.24
# SEO.0
# SEO.1
# SEO.2
# SEO.3
# SEO.4
# SEO.5
# SEO.6
# SEO.7
# SEO.8
# SEO.9
# SEO.10
# SEO.11
# SEO.12
# SEO.13
# SEO.14
# SEO.15
# SEO.16
# SEO.17
# SEO.18
# SEO.19
# Grant.Status

# %%
df == df2
# Out:
#       A..papers  A.papers  B.papers  C.papers  Dif.countries  \
# 0          True      True      True      True           True
# 1          True      True      True      True           True
# 2          True      True      True      True           True
# 3          True      True      True      True           True
# 4          True      True      True      True           True
# 5          True      True      True      True           True
# 6          True      True      True      True           True
# 7          True      True      True      True           True
# 8          True      True      True      True           True
# 9          True      True      True      True           True
# 10         True      True      True      True           True
# 11         True      True      True      True           True
# 12         True      True      True      True           True
# 13         True      True      True      True           True
# 14         True      True      True      True           True
# 15         True      True      True      True           True
# 16         True      True      True      True           True
# 17         True      True      True      True           True
# 18         True      True      True      True           True
# 19         True      True      True      True           True
# 20         True      True      True      True           True
# 21         True      True      True      True           True
# 22         True      True      True      True           True
# 23         True      True      True      True           True
# 24         True      True      True      True           True
# 25         True      True      True      True           True
# 26         True      True      True      True           True
# 27         True      True      True      True           True
# 28         True      True      True      True           True
# 29         True      True      True      True           True
# ...         ...       ...       ...       ...            ...
# 8678       True      True      True      True           True
# 8679       True      True      True      True           True
# 8680       True      True      True      True           True
# 8681       True      True      True      True           True
# 8682       True      True      True      True           True
# 8683       True      True      True      True           True
# 8684       True      True      True      True           True
# 8685       True      True      True      True           True
# 8686       True      True      True      True           True
# 8687       True      True      True      True           True
# 8688       True      True      True      True           True
# 8689       True      True      True      True           True
# 8690       True      True      True      True           True
# 8691       True      True      True      True           True
# 8692       True      True      True      True           True
# 8693       True      True      True      True           True
# 8694       True      True      True      True           True
# 8695       True      True      True      True           True
# 8696       True      True      True      True           True
# 8697       True      True      True      True           True
# 8698       True      True      True      True           True
# 8699       True      True      True      True           True
# 8700       True      True      True      True           True
# 8701       True      True      True      True           True
# 8702       True      True      True      True           True
# 8703       True      True      True      True           True
# 8704       True      True      True      True           True
# 8705       True      True      True      True           True
# 8706       True      True      True      True           True
# 8707       True      True      True      True           True
#
#       Perc_non_australian  Number.people   PHD  Max.years.univ  Grants.succ  \
# 0                    True           True  True            True         True
# 1                    True           True  True            True         True
# 2                   False           True  True            True         True
# 3                    True           True  True            True         True
# 4                    True           True  True            True         True
# 5                    True           True  True            True         True
# 6                   False           True  True            True         True
# 7                    True           True  True            True         True
# 8                    True           True  True            True         True
# 9                    True           True  True            True         True
# 10                   True           True  True            True         True
# 11                   True           True  True            True         True
# 12                   True           True  True            True         True
# 13                   True           True  True            True         True
# 14                  False           True  True            True         True
# 15                   True           True  True            True         True
# 16                   True           True  True            True         True
# 17                   True           True  True            True         True
# 18                   True           True  True            True         True
# 19                   True           True  True            True         True
# 20                   True           True  True            True         True
# 21                   True           True  True            True         True
# 22                   True           True  True            True         True
# 23                   True           True  True            True         True
# 24                   True           True  True            True         True
# 25                   True           True  True            True         True
# 26                   True           True  True            True         True
# 27                   True           True  True            True         True
# 28                   True           True  True            True         True
# 29                  False           True  True            True         True
# ...                   ...            ...   ...             ...          ...
# 8678                 True           True  True            True         True
# 8679                 True           True  True            True         True
# 8680                 True           True  True            True         True
# 8681                 True           True  True            True         True
# 8682                 True           True  True            True         True
# 8683                 True           True  True            True         True
# 8684                 True           True  True            True         True
# 8685                 True           True  True            True         True
# 8686                 True           True  True            True         True
# 8687                 True           True  True            True         True
# 8688                False           True  True            True         True
# 8689                 True           True  True            True         True
# 8690                 True           True  True            True         True
# 8691                 True           True  True            True         True
# 8692                 True           True  True            True         True
# 8693                 True           True  True            True         True
# 8694                 True           True  True            True         True
# 8695                 True           True  True            True         True
# 8696                 True           True  True            True         True
# 8697                 True           True  True            True         True
# 8698                 True           True  True            True         True
# 8699                 True           True  True            True         True
# 8700                 True           True  True            True         True
# 8701                False           True  True            True         True
# 8702                 True           True  True            True         True
# 8703                 True           True  True            True         True
# 8704                 True           True  True            True         True
# 8705                 True           True  True            True         True
# 8706                 True           True  True            True         True
# 8707                 True           True  True            True         True
#
#           ...       SEO.11  SEO.12  SEO.13  SEO.14  SEO.15  SEO.16  SEO.17  \
# 0         ...         True    True    True    True    True    True    True
# 1         ...         True    True    True    True    True    True    True
# 2         ...         True    True    True    True    True    True    True
# 3         ...         True    True    True    True    True    True    True
# 4         ...         True    True    True    True    True    True    True
# 5         ...         True    True    True    True    True    True    True
# 6         ...         True    True    True    True    True    True    True
# 7         ...         True    True    True    True    True    True    True
# 8         ...         True    True    True    True    True    True    True
# 9         ...         True    True    True    True    True    True    True
# 10        ...         True    True    True    True    True    True    True
# 11        ...         True    True    True    True    True    True    True
# 12        ...         True    True    True    True    True    True    True
# 13        ...         True    True    True    True    True    True    True
# 14        ...         True    True    True    True    True    True    True
# 15        ...         True    True    True    True    True    True    True
# 16        ...         True    True    True    True    True    True    True
# 17        ...         True    True    True    True    True    True    True
# 18        ...         True    True    True    True    True    True    True
# 19        ...         True    True    True    True    True    True    True
# 20        ...         True    True    True    True    True    True    True
# 21        ...         True    True    True    True    True    True    True
# 22        ...         True    True    True    True    True    True    True
# 23        ...         True    True    True    True    True    True    True
# 24        ...         True    True    True    True    True    True    True
# 25        ...         True    True    True    True    True    True    True
# 26        ...         True    True    True    True    True    True    True
# 27        ...         True    True    True    True    True    True    True
# 28        ...         True    True    True    True    True    True    True
# 29        ...         True    True    True    True    True    True    True
# ...       ...          ...     ...     ...     ...     ...     ...     ...
# 8678      ...         True    True    True    True    True    True    True
# 8679      ...         True    True    True    True    True    True    True
# 8680      ...         True    True    True    True    True    True    True
# 8681      ...         True    True    True    True    True    True    True
# 8682      ...         True    True    True    True    True    True    True
# 8683      ...         True    True    True    True    True    True    True
# 8684      ...         True    True    True    True    True    True    True
# 8685      ...         True    True    True    True    True    True    True
# 8686      ...         True    True    True    True    True    True    True
# 8687      ...         True    True    True    True    True    True    True
# 8688      ...         True    True    True    True    True    True    True
# 8689      ...         True    True    True    True    True    True    True
# 8690      ...         True    True    True    True    True    True    True
# 8691      ...         True    True    True    True    True    True    True
# 8692      ...         True    True    True    True    True    True    True
# 8693      ...         True    True    True    True    True    True    True
# 8694      ...         True    True    True    True    True    True    True
# 8695      ...         True    True    True    True    True    True    True
# 8696      ...         True    True    True    True    True    True    True
# 8697      ...         True    True    True    True    True    True    True
# 8698      ...         True    True    True    True    True    True    True
# 8699      ...         True    True    True    True    True    True    True
# 8700      ...         True    True    True    True    True    True    True
# 8701      ...         True    True    True    True    True    True    True
# 8702      ...         True    True    True    True    True    True    True
# 8703      ...         True    True    True    True    True    True    True
# 8704      ...         True    True    True    True    True    True    True
# 8705      ...         True    True    True    True    True    True    True
# 8706      ...         True    True    True    True    True    True    True
# 8707      ...         True    True    True    True    True    True    True
#
#       SEO.18  SEO.19  Grant.Status
# 0       True    True          True
# 1       True    True          True
# 2       True    True          True
# 3       True    True          True
# 4       True    True          True
# 5       True    True          True
# 6       True    True          True
# 7       True    True          True
# 8       True    True          True
# 9       True    True          True
# 10      True    True          True
# 11      True    True          True
# 12      True    True          True
# 13      True    True          True
# 14      True    True          True
# 15      True    True          True
# 16      True    True          True
# 17      True    True          True
# 18      True    True          True
# 19      True    True          True
# 20      True    True          True
# 21      True    True          True
# 22      True    True          True
# 23      True    True          True
# 24      True    True          True
# 25      True    True          True
# 26      True    True          True
# 27      True    True          True
# 28      True    True          True
# 29      True    True          True
# ...      ...     ...           ...
# 8678    True    True          True
# 8679    True    True          True
# 8680    True    True          True
# 8681    True    True          True
# 8682    True    True          True
# 8683    True    True          True
# 8684    True    True          True
# 8685    True    True          True
# 8686    True    True          True
# 8687    True    True          True
# 8688    True    True          True
# 8689    True    True          True
# 8690    True    True          True
# 8691    True    True          True
# 8692    True    True          True
# 8693    True    True          True
# 8694    True    True          True
# 8695    True    True          True
# 8696    True    True          True
# 8697    True    True          True
# 8698    True    True          True
# 8699    True    True          True
# 8700    True    True          True
# 8701    True    True          True
# 8702    True    True          True
# 8703    True    True          True
# 8704    True    True          True
# 8705    True    True          True
# 8706    True    True          True
# 8707    True    True          True
#
# [8708 rows x 71 columns]

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

plt.style.use('ggplot')
# plt.style.use('default')

# %%
plt.hist(dfgg, align='left', rwidth=0.5, bins=range(0, 16))
plt.xlabel("# of people in team")
plt.show()

# %%
dfg = df.groupby('Number.people')['Number.people'].count()
dfg.index = dfg.index.astype(int)
dfg
# Out:
# Number.people
# 0      468
# 1     5282
# 2     1840
# 3      699
# 4      259
# 5       85
# 6       53
# 7        9
# 8        4
# 9        2
# 10       1
# 12       2
# 13       1
# 14       2
# Name: Number.people, dtype: int64

# %%
dfgg = df['Number.people']
dfgg.index += 1

# %%
(df3[['Person.ID.{}'.format(attr) for attr in range(1, 16)]].notna().sum(axis=1) == 0).sum()
# Out:
# 468

# %%
dfrfcd = (df3[['RFCD.Code.{}'.format(attr) for attr in range(1, 6)]].fillna(0) != 0).sum(axis=1)
plt.hist(dfrfcd, align='left', rwidth=0.5, bins=range(0, 7))
plt.xlabel("# of RECD in team")
plt.show()

# %%
dfseo = (df3[['SEO.Code.{}'.format(attr) for attr in range(1, 6)]].fillna(0) != 0).sum(axis=1)
plt.hist(dfseo, align='left', rwidth=0.5, bins=range(0, 7))
plt.xlabel("# of SEO in team")
plt.show()

# %%
# Out:
# A..papers                  float64
# A.papers                   float64
# B.papers                   float64
# C.papers                   float64
# Dif.countries              float64
# Perc_non_australian        float64
# Number.people              float64
# PHD                        float64
# Max.years.univ             float64
# Grants.succ                float64
# Grants.unsucc              float64
# Departments                float64
# Perc.Lang.Eng              float64
# Perc.Lang.Other            float64
# Dif.Role                   float64
# Perc.CHIEF.INVESTIGATOR    float64
# Average.Age                float64
# Weekday                    float64
# Month                      float64
# Day.of.Month               float64
# Day.of.Year                float64
# Season                     float64
# Sponsor.Code               float64
# Grant.Category.Code        float64
# Contract.Value.Band        float64
# RFCD.0                     float64
# RFCD.1                     float64
# RFCD.2                     float64
# RFCD.3                     float64
# RFCD.4                     float64
#                             ...
# RFCD.16                    float64
# RFCD.17                    float64
# RFCD.18                    float64
# RFCD.19                    float64
# RFCD.20                    float64
# RFCD.21                    float64
# RFCD.22                    float64
# RFCD.23                    float64
# RFCD.24                    float64
# SEO.0                      float64
# SEO.1                      float64
# SEO.2                      float64
# SEO.3                      float64
# SEO.4                      float64
# SEO.5                      float64
# SEO.6                      float64
# SEO.7                      float64
# SEO.8                      float64
# SEO.9                      float64
# SEO.10                     float64
# SEO.11                     float64
# SEO.12                     float64
# SEO.13                     float64
# SEO.14                     float64
# SEO.15                     float64
# SEO.16                     float64
# SEO.17                     float64
# SEO.18                     float64
# SEO.19                     float64
# Grant.Status               float64
# Length: 71, dtype: object

# %%
import torch
import torchvision.datasets as datasets
import torchvision.transforms as transforms

# %%
data_loader = torch.utils.data.DataLoader(datasets.MNIST('../data', train=True, download=True,
                                                         transform=transforms.Compose([
                                                         transforms.ToTensor(),
                                                         transforms.Normalize((0.1307,), (0.3081,)),
                                                         transforms.Lambda(lambda x: x.view(-1) )
                                                       ])),
                                        batch_size=128, shuffle=True)

# %%
for data, label in data_loader:
    print(data.size())
    break
# Out:
# torch.Size([128, 784])
